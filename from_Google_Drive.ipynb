# %% [markdown]
# <a href="https://colab.research.google.com/github/rtheman/Data_IO/blob/master/from_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objective
#
# This notebook provide receipes for loading/extracting data into this Juypter Notebook (Google Colab), in this case, from **Google Drive**.
#
# There are 3-ways to connect:
# 1. Mounting your Google Drive in the runtime's virtual machine
# 1. Using a wrapper around the API such as [PyDrive](https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html)
# 1. Using the [native REST API](https://developers.google.com/drive/v3/web/about-sdk)
#
# This notebook will focus on method (1.) by mounting Google Drive to Colab.
#
# To find out more about connecting via method 2 or 3, please refer to https://colab.research.google.com/notebooks/io.ipynb#scrollTo=c2W5A2px3doP

# %% [markdown]
# # Init. settings and libraries
#
# This step authorize Colab to access your Google Drive.
#
# **NOTE**: `drive.mount` mount your Google Drive file structure at Colab file system destination as specified.
#
# ```
# # This is formatted as code
# ```

# %%
from google.colab import drive
drive.mount('/content/g_drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/g_drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1.) Ingest data as dataframe

# %% [markdown]
# ## a. Init. paths and file names

# %%
import pandas as pd

# %%
data_URL = "./g_drive/My Drive/Colab Notebooks/data/_Samples/"
data_filename = "COVID_Active_Cases_USA_NY.csv"

# %% [markdown]
# ## b. Save as dataframe

# %%
path = data_URL + data_filename

df = pd.read_csv(path, header=0, index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 2020-03-12 to 2020-06-20
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Active_Cases  101 non-null    int64
# dtypes: int64(1)
# memory usage: 1.6+ KB

# %%
df.dtypes
# Out:
# Active_Cases    int64
# dtype: object

# %%
df
# Out:
#              Active_Cases
# Observ_Date
# 2020-03-12            328
# 2020-03-13            421
# 2020-03-14            524
# 2020-03-15            729
# 2020-03-16            956
# ...                   ...
# 2020-06-16         288566
# 2020-06-17         288954
# 2020-06-18         290469
# 2020-06-19         291432
# 2020-06-20         292129
#
# [101 rows x 1 columns]
